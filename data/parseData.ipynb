# %%
import pandas as pd

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
data = pd.read_csv('2015_data.csv',  
                   dtype={'education_reporting_flag': int, 'age_recode_52': str
                   },low_memory=False)

# %%
data.describe()
# Out:
#        resident_status  education_1989_revision  education_2003_revision  \
# count     2.718198e+06             73043.000000             2.645155e+06
# mean      1.226700e+00                12.602371             3.718700e+00
# std       4.993832e-01                 9.516661             1.985368e+00
# min       1.000000e+00                 0.000000             1.000000e+00
# 25%       1.000000e+00                11.000000             3.000000e+00
# 50%       1.000000e+00                12.000000             3.000000e+00
# 75%       1.000000e+00                13.000000             5.000000e+00
# max       4.000000e+00                99.000000             9.000000e+00
#
#        education_reporting_flag  month_of_death  detail_age_type  \
# count              2.718198e+06    2.718198e+06     2.718198e+06
# mean               9.731282e-01    6.381973e+00     1.025770e+00
# std                1.617089e-01    3.520758e+00     3.105674e-01
# ...

# %%
data_resident = data[data['resident_status'] == 1]

# %%
len(data_resident)
# Out:
# 2197091

# %%
group_by_age = data_resident[['age_recode_52', '39_cause_recode']].groupby('age_recode_52')
count_by_age = group_by_age.agg('count')

# %%
percentage_by_age = 100*count_by_age/len(data_resident)

# %%
s = data['39_cause_recode'].groupby(data['age_recode_52']).value_counts()

# %%
w = s.groupby(level=0).nlargest(5).reset_index(level=0, drop=True)

# %%
w.to_csv("cat_2015.csv")
